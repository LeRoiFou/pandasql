# %% [markdown]
# # L'opérateur SELECT
# ---

# %% [markdown]
# > Syntaxe en sélectionnant plusieurs colonnes
# > ```
# > SELECT *
# > FROM table;
# > ```
# > <br>

# %% [markdown]
# > Syntaxe en sélectionnant une seule colonne
# > ```
# > SELECT colonne
# > FROM table;
# > ```
# > <br>

# %% [markdown]
# > Syntaxe en sélectionnant plusieurs colonnes
# > ```
# > SELECT
# >     colonne1
# >     , colonne2
# > FROM table;
# > ```
# > <br>

# %%
import pandas as pd
from skimpy import skim
from sqlalchemy import create_engine

# %%
# Connection à la BD PostgreSQL : 
# nom_utilisateurr:mdp@adresse:port/nom_du_projet
engine = create_engine(
    'postgresql://laurent:test22@localhost:5432/test1',)

# %% [markdown]
# ## Fichier des produits

# %%
# Requête SQL : récupération de toutes les données du fichier .csv en DF
query = """
SELECT *
FROM products_dim;
"""
products_df = pd.read_sql(sql=query, con=engine)
products_df.head(2).transpose()
# Out:
#                                                                0  \
# ProduitID                                                      1
# NomProduit                                    Samsung Galaxy S21
# Description    Featuring a 6.2-inch dynamic AMOLED display, t...
# PrixUnitaire                                                 699
# FournisseurID                                                  4
#
#                                                                1
# ProduitID                                                      2
# NomProduit                                        Samsung TV 55'
# Description    55-inch 4K UHD Smart TV with HDR, Crystal Disp...
# PrixUnitaire                                                 129
# FournisseurID                                                 51

# %%
skim(products_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 100    │ │ string      │ 4     │                                                          │
# │ │ Number of columns │ 5      │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column             ┃ NA   ┃ NA %    ┃ mean     ┃ sd       ┃ p0   ┃ p25   ┃ p50   ┃ p75   ┃ p100  ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━┩  │
# │ │ PrixUnitaire       │    0 │       0 │    486.7 │    326.6 │   59 │   129 │   399 │   699 │   999 │ ▇▃▂ ▇▃  │  │
# │ └────────────────────┴──────┴─────────┴──────────┴──────────┴──────┴───────┴───────┴───────┴───────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┓  │
# │ ┃           ┃    ┃      ┃           ┃           ┃           ┃           ┃ chars per ┃ words per ┃ total      ┃  │
# │ ┃ column    ┃ NA ┃ NA % ┃ shortest  ┃ longest   ┃ min       ┃ max       ┃ row       ┃ row       ┃ words      ┃  │
# │ ┡━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━┩  │
# │ │ ProduitID │  0 │    0 │ 1         │ 100       │ 1         │ 99        │      1.92 │         1 │        100 │  │
# │ │ NomProdui │  0 │    0 │ iPhone 12 │ Ralph     │ Dell XPS  │ iPhone 12 │      13.6 │       2.7 │        266 │  │
# │ │ t         │    │      │           │ Lauren    │ 13        │           │           │           │            │  │
# │ │           │    │      │           │ Polo      │           │           │           │           │            │  │
# │ │           │    │      │           │ Shirt     │           │           │           │           │            │  │
# │ │ Descripti │  0 │    0 │ A         │ Cordless  │ 13.4-inch │ Stand     │      87.3 │        14 │       1371 │  │
# │ │ on        │    │      │ 6.1-inch  │ vacuum    │ FHD+      │ mixer     │           │           │            │  │
# │ │           │    │      │ smartphon │ cleaner   │ laptop    │ with      │           │           │            │  │
# │ │           │    │      │ e with    │ with      │ with 10th │ 10-speed  │           │           │            │  │
# │ │           │    │      │ A14       │ strong    │ Gen Intel │ settings, │           │           │            │  │
# │ │           │    │      │ Bionic    │ suction   │ Core      │ a         │           │           │            │  │
# │ │           │    │      │ chip,     │ power,    │ processor │ tilt-head │           │           │            │  │
# │ │           │    │      │ dual-came │ multiple  │ s and a   │ design,   │           │           │            │  │
# │ │           │    │      │ ra        │ attachmen │ stunning  │ and comes │           │           │            │  │
# │ │           │    │      │ system,   │ ts, and   │ HDR 400   │ with      │           │           │            │  │
# │ │           │    │      │ and 5G    │ up to 60  │ display.  │ multiple  │           │           │            │  │
# │ │           │    │      │ speed.    │ minutes   │           │ attachmen │           │           │            │  │
# │ │           │    │      │           │ of run    │           │ ts.       │           │           │            │  │
# │ │           │    │      │           │ time.     │           │           │           │           │            │  │
# │ │ Fournisse │  0 │    0 │ 4         │ 100       │ 1         │ 98        │      1.92 │         1 │        100 │  │
# │ │ urID      │    │      │           │           │           │           │           │           │            │  │
# │ └───────────┴────┴──────┴───────────┴───────────┴───────────┴───────────┴───────────┴───────────┴────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## Fichier des clients

# %%
# Requête SQL : récupération de toutes les données du fichier .csv
query = """
SELECT *
FROM customers_dim;
"""
customers_df = pd.read_sql(sql=query, con=engine)
customers_df.head(2).transpose()
# Out:
#                                                     0  \
# ClientID                                            1
# Nom                                          Thompson
# Prenom                                        Shannon
# Adresse          384 Howard Parks, New Tony, DE 67522
# Email                      thompson.shannon@gmail.com
# NumeroTelephone                             425163679
#
#                                                                  1
# ClientID                                                         2
# Nom                                                           Pham
# Prenom                                                    Benjamin
# Adresse          15250 Anita Pine Apt. 887, New Kristenport, AR...
# Email                                      pham.benjamin@gmail.com
# NumeroTelephone                                          544573781

# %%
skim(customers_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 100    │ │ string      │ 6     │                                                          │
# │ │ Number of columns │ 6      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┓  │
# │ ┃           ┃    ┃      ┃           ┃           ┃           ┃           ┃ chars per ┃ words per ┃ total      ┃  │
# │ ┃ column    ┃ NA ┃ NA % ┃ shortest  ┃ longest   ┃ min       ┃ max       ┃ row       ┃ row       ┃ words      ┃  │
# │ ┡━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━┩  │
# │ │ ClientID  │  0 │    0 │ 1         │ 100       │ 1         │ 99        │      1.92 │         1 │        100 │  │
# │ │ Nom       │  0 │    0 │ Pham      │ Cunningha │ Abbott    │ Wilson    │      6.37 │         1 │        100 │  │
# │ │           │    │      │           │ m         │           │           │           │           │            │  │
# │ │ Prenom    │  0 │    0 │ Zoe       │ Christoph │ Aaron     │ Zoe       │      6.14 │         1 │        100 │  │
# │ │           │    │      │           │ er        │           │           │           │           │            │  │
# │ │ Adresse   │  0 │    0 │ USS Lee,  │ 925       │ 00041     │ Unit 6947 │      43.5 │       7.3 │        732 │  │
# │ │           │    │      │ FPO AP    │ Robertson │ Green     │ Box 2102, │           │           │            │  │
# │ │           │    │      │ 23687     │ Springs   │ Street,   │ DPO AP    │           │           │            │  │
# │ │           │    │      │           │ Suite     │ Stephenbo │ 84355     │           │           │            │  │
# │ │           │    │      │           │ 489, Port │ rough, UT │           │           │           │            │  │
# │ │           │    │      │           │ Jeffreybe │ 34030     │           │           │           │            │  │
# │ │           │    │      │           │ rg, IN    │           │           │           │           │            │  │
# │ │           │    │      │           │ 43983     │           │           │           │           │            │  │
# │ │ Email     │  0 │    0 │ snow.zoe@ │ richardso │ abbott.kr │ wilson.vi │      23.5 │         1 │        100 │  │
# │ │           │    │      │ gmail.com │ n.cheyenn │ isten@gma │ ncent@gma │           │           │            │  │
# │ │           │    │      │           │ e@gmail.c │ il.com    │ il.com    │           │           │            │  │
# │ │           │    │      │           │ om        │           │           │           │           │            │  │
# │ │ NumeroTel │  0 │    0 │ 1375633   │ 425163679 │ 117405460 │ 994074144 │      8.86 │         1 │        100 │  │
# │ │ ephone    │    │      │           │           │           │           │           │           │            │  │
# │ └───────────┴────┴──────┴───────────┴───────────┴───────────┴───────────┴───────────┴───────────┴────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## Fichier des fournisseurs

# %%
query = """
SELECT *
FROM suppliers_dim ;
"""
suppliers_df = pd.read_sql(sql=query, con=engine)
suppliers_df.head(2).transpose()
# Out:
#                                                             0  \
# FournisseurID                                               1
# NomFournisseur                      Nelson, Smith and Jackson
# Adresse          74883 Kimberly Shore, Stewartmouth, VA 11290
# Email                        nelson_smithandjackson@gmail.com
# NumeroTelephone                                     399791118
#
#                                                                  1
# FournisseurID                                                    2
# NomFournisseur                            Jones, Hodge and Burgess
# Adresse          32014 Andrew Tunnel Suite 839, Campbellport, H...
# Email                              jones_hodgeandburgess@gmail.com
# NumeroTelephone                                          822754147

# %% [markdown]
# ## Requêtes SQL

# %% [markdown]
# Donner la table complète des clients de l'entreprise

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim;
"""
pd.read_sql(sql=query, con=engine)
# Out:
#    ClientID        Nom     Prenom  \
# 0         1   Thompson    Shannon
# 1         2       Pham   Benjamin
# 2         3  Rodriguez     Bonnie
# 3         4      Perez  Stephanie
# 4         5     Kramer      Joyce
# ..      ...        ...        ...
# 95       96  Rodriguez      Tammy
# 96       97     Hunter   Kimberly
# 97       98       Hess       Ryan
# 98       99     Harvey    Michael
# 99      100   Campbell     Jordan
#
#                                               Adresse  \
# 0                384 Howard Parks, New Tony, DE 67522
# 1   15250 Anita Pine Apt. 887, New Kristenport, AR...
# 2   515 Henderson Coves Apt. 298, Lewismouth, OR 1...
# 3    619 Juan Parkways Suite 983, Tracibury, NM 13549
# 4   85731 Danny Groves Suite 513, Lake Michaelvill...
# ..                                                ...
# 95                             USS Berg, FPO AP 26777
# 96      99327 Lewis Glens, West Patrickstad, FL 88083
# 97                   Unit 4039 Box 6603, DPO AE 40744
# 98        6742 Jackson Corner, South Isabel, VT 46191
# 99  9418 Salazar Forks Suite 382, Lake Paul, NJ 71313
#
#                          Email NumeroTelephone
# 0   thompson.shannon@gmail.com       425163679
# 1      pham.benjamin@gmail.com       544573781
# 2   rodriguez.bonnie@gmail.com       956054323
# 3    perez.stephanie@gmail.com        37851314
# 4       kramer.joyce@gmail.com       705010731
# ..                         ...             ...
# 95   rodriguez.tammy@gmail.com       198156282
# 96   hunter.kimberly@gmail.com       503857599
# 97         hess.ryan@gmail.com       508092073
# 98    harvey.michael@gmail.com       192649531
# 99   campbell.jordan@gmail.com        25669814
#
# [100 rows x 6 columns]

# %% [markdown]
# Donner la table complète des produits vendus par l'entreprise

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM products_dim;
"""
pd.read_sql(sql=query, con=engine)
# Out:
#    ProduitID          NomProduit  \
# 0          1  Samsung Galaxy S21
# 1          2      Samsung TV 55'
# 2          3        Nike Air Max
# 3          4        Levi's Jeans
# 4          5        Dyson Vacuum
# ..       ...                 ...
# 95        96           iPhone 12
# 96        97           iPhone 12
# 97        98         Dell XPS 13
# 98        99        Dyson Vacuum
# 99       100      Samsung TV 55'
#
#                                           Description  PrixUnitaire  \
# 0   Featuring a 6.2-inch dynamic AMOLED display, t...           699
# 1   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           129
# 2   Running shoes with Max Air cushioning, mesh up...            85
# 3   Classic denim jeans with a straight leg fit, f...           299
# 4   Cordless vacuum cleaner with strong suction po...           999
# ..                                                ...           ...
# 95  A 6.1-inch smartphone with A14 Bionic chip, du...           699
# 96  A 6.1-inch smartphone with A14 Bionic chip, du...           999
# 97  13.4-inch FHD+ laptop with 10th Gen Intel Core...           799
# 98  Cordless vacuum cleaner with strong suction po...           999
# 99  55-inch 4K UHD Smart TV with HDR, Crystal Disp...           299
#
#    FournisseurID
# 0              4
# 1             51
# 2             93
# 3              8
# 4             58
# ..           ...
# 95            42
# 96            86
# 97            33
# 98            84
# 99            16
#
# [100 rows x 5 columns]

# %% [markdown]
# Donner le nom de tous les produits de la base de données

# %%
query = """
-- Colonnes récupérées
SELECT DISTINCT("NomProduit") AS "Liste des produits"
-- BD récupérée
FROM products_dim;
"""
pd.read_sql(sql=query, con=engine)
# Out:
#         Liste des produits
# 0  Ralph Lauren Polo Shirt
# 1             Nike Air Max
# 2         KitchenAid Mixer
# 3           Samsung TV 55'
# 4       Samsung Galaxy S21
# 5             Levi's Jeans
# 6             Dyson Vacuum
# 7                iPhone 12
# 8              Dell XPS 13

# %% [markdown]
# Donner le nom de tous les fournisseurs dans la BD

# %%
query = """
-- Colonnes récupérées
SELECT DISTINCT("NomFournisseur") AS "Liste des fournisseurs"
-- BD récupérée
FROM suppliers_dim;
"""
pd.read_sql(sql=query, con=engine)
# Out:
#           Liste des fournisseurs
# 0     Smith, Trujillo and Brandt
# 1   Nguyen, Macias and Contreras
# 2                     Jacobs PLC
# 3                    Woods Group
# 4                     Murphy Inc
# ..                           ...
# 95                Schultz-Malone
# 96                 Bowman-Kramer
# 97                Graham-Gilbert
# 98            Davenport and Sons
# 99     Salazar, Palmer and Gomez
#
# [100 rows x 1 columns]

# %% [markdown]
# Donne le nom et l'ID de tous les fournisseurs de la BD

# %%
suppliers_df.head(2).transpose()
# Out:
#                                                             0  \
# FournisseurID                                               1
# NomFournisseur                      Nelson, Smith and Jackson
# Adresse          74883 Kimberly Shore, Stewartmouth, VA 11290
# Email                        nelson_smithandjackson@gmail.com
# NumeroTelephone                                     399791118
#
#                                                                  1
# FournisseurID                                                    2
# NomFournisseur                            Jones, Hodge and Burgess
# Adresse          32014 Andrew Tunnel Suite 839, Campbellport, H...
# Email                              jones_hodgeandburgess@gmail.com
# NumeroTelephone                                          822754147

# %%
query = """
-- Colonnes récupérées
SELECT 
    "FournisseurID"
    , "NomFournisseur"
-- BD récupérée
FROM suppliers_dim;
"""
pd.read_sql(sql=query, con=engine)
# Out:
#    FournisseurID             NomFournisseur
# 0              1  Nelson, Smith and Jackson
# 1              2   Jones, Hodge and Burgess
# 2              3                 Howard Inc
# 3              4               Jenkins-Gray
# 4              5                  Cohen LLC
# ..           ...                        ...
# 95            96  Chen, Jackson and Preston
# 96            97               Avila-Thomas
# 97            98                Perez-Brown
# 98            99            Johnson-Ramirez
# 99           100                  Lopez Ltd
#
# [100 rows x 2 columns]
