# %% [markdown]
# # L'opérateur REGEX
# ---

# %% [markdown]
# > Syntaxe :
# > ```
# > SELECT nom_colonne
# > FROM nom_table
# > WHERE nom_colonne REGEXP 'pattern';
# > ```
# > <br>

# %%
import pandas as pd
from skimpy import skim
from sqlalchemy import create_engine

# %%
# Connection à postgresql
engine = create_engine(
    'postgresql://laurent:test22@localhost:5432/test1')

# %% [markdown]
# ## Fichier des produits

# %%
# Récupération des données de la table products_dim
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM products_dim;
"""
products_df = pd.read_sql(sql=query, con=engine)

# %%
products_df.head().transpose()
# Out:
#                                                                0  \
# ProduitID                                                      1
# NomProduit                                    Samsung Galaxy S21
# Description    Featuring a 6.2-inch dynamic AMOLED display, t...
# PrixUnitaire                                                 699
# FournisseurID                                                  4
#
#                                                                1  \
# ProduitID                                                      2
# NomProduit                                        Samsung TV 55'
# Description    55-inch 4K UHD Smart TV with HDR, Crystal Disp...
# PrixUnitaire                                                 129
# FournisseurID                                                 51
#
#                                                                2  \
# ProduitID                                                      3
# NomProduit                                          Nike Air Max
# Description    Running shoes with Max Air cushioning, mesh up...
# PrixUnitaire                                                  85
# FournisseurID                                                 93
#
#                                                                3  \
# ProduitID                                                      4
# NomProduit                                          Levi's Jeans
# Description    Classic denim jeans with a straight leg fit, f...
# PrixUnitaire                                                 299
# FournisseurID                                                  8
#
#                                                                4
# ProduitID                                                      5
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 999
# FournisseurID                                                 58

# %%
skim(products_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 100    │ │ string      │ 4     │                                                          │
# │ │ Number of columns │ 5      │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column             ┃ NA   ┃ NA %    ┃ mean     ┃ sd       ┃ p0   ┃ p25   ┃ p50   ┃ p75   ┃ p100  ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━┩  │
# │ │ PrixUnitaire       │    0 │       0 │    486.7 │    326.6 │   59 │   129 │   399 │   699 │   999 │ ▇▃▂ ▇▃  │  │
# │ └────────────────────┴──────┴─────────┴──────────┴──────────┴──────┴───────┴───────┴───────┴───────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┓  │
# │ ┃           ┃    ┃      ┃           ┃           ┃           ┃           ┃ chars per ┃ words per ┃ total      ┃  │
# │ ┃ column    ┃ NA ┃ NA % ┃ shortest  ┃ longest   ┃ min       ┃ max       ┃ row       ┃ row       ┃ words      ┃  │
# │ ┡━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━┩  │
# │ │ ProduitID │  0 │    0 │ 1         │ 100       │ 1         │ 99        │      1.92 │         1 │        100 │  │
# │ │ NomProdui │  0 │    0 │ iPhone 12 │ Ralph     │ Dell XPS  │ iPhone 12 │      13.6 │       2.7 │        266 │  │
# │ │ t         │    │      │           │ Lauren    │ 13        │           │           │           │            │  │
# │ │           │    │      │           │ Polo      │           │           │           │           │            │  │
# │ │           │    │      │           │ Shirt     │           │           │           │           │            │  │
# │ │ Descripti │  0 │    0 │ A         │ Cordless  │ 13.4-inch │ Stand     │      87.3 │        14 │       1371 │  │
# │ │ on        │    │      │ 6.1-inch  │ vacuum    │ FHD+      │ mixer     │           │           │            │  │
# │ │           │    │      │ smartphon │ cleaner   │ laptop    │ with      │           │           │            │  │
# │ │           │    │      │ e with    │ with      │ with 10th │ 10-speed  │           │           │            │  │
# │ │           │    │      │ A14       │ strong    │ Gen Intel │ settings, │           │           │            │  │
# │ │           │    │      │ Bionic    │ suction   │ Core      │ a         │           │           │            │  │
# │ │           │    │      │ chip,     │ power,    │ processor │ tilt-head │           │           │            │  │
# │ │           │    │      │ dual-came │ multiple  │ s and a   │ design,   │           │           │            │  │
# │ │           │    │      │ ra        │ attachmen │ stunning  │ and comes │           │           │            │  │
# │ │           │    │      │ system,   │ ts, and   │ HDR 400   │ with      │           │           │            │  │
# │ │           │    │      │ and 5G    │ up to 60  │ display.  │ multiple  │           │           │            │  │
# │ │           │    │      │ speed.    │ minutes   │           │ attachmen │           │           │            │  │
# │ │           │    │      │           │ of run    │           │ ts.       │           │           │            │  │
# │ │           │    │      │           │ time.     │           │           │           │           │            │  │
# │ │ Fournisse │  0 │    0 │ 4         │ 100       │ 1         │ 98        │      1.92 │         1 │        100 │  │
# │ │ urID      │    │      │           │           │           │           │           │           │            │  │
# │ └───────────┴────┴──────┴───────────┴───────────┴───────────┴───────────┴───────────┴───────────┴────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## Fichier des clients

# %%
# Récupération des données de la table products_dim
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim;
"""
customers_df = pd.read_sql(sql=query, con=engine)

# %%
customers_df.head().transpose()
# Out:
#                                                     0  \
# ClientID                                            1
# Nom                                          Thompson
# Prenom                                        Shannon
# Adresse          384 Howard Parks, New Tony, DE 67522
# Email                      thompson.shannon@gmail.com
# NumeroTelephone                             425163679
#
#                                                                  1  \
# ClientID                                                         2
# Nom                                                           Pham
# Prenom                                                    Benjamin
# Adresse          15250 Anita Pine Apt. 887, New Kristenport, AR...
# Email                                      pham.benjamin@gmail.com
# NumeroTelephone                                          544573781
#
#                                                                  2  \
# ClientID                                                         3
# Nom                                                      Rodriguez
# Prenom                                                      Bonnie
# Adresse          515 Henderson Coves Apt. 298, Lewismouth, OR 1...
# Email                                   rodriguez.bonnie@gmail.com
# NumeroTelephone                                          956054323
#
#                                                                 3  \
# ClientID                                                        4
# Nom                                                         Perez
# Prenom                                                  Stephanie
# Adresse          619 Juan Parkways Suite 983, Tracibury, NM 13549
# Email                                   perez.stephanie@gmail.com
# NumeroTelephone                                          37851314
#
#                                                                  4
# ClientID                                                         5
# Nom                                                         Kramer
# Prenom                                                       Joyce
# Adresse          85731 Danny Groves Suite 513, Lake Michaelvill...
# Email                                       kramer.joyce@gmail.com
# NumeroTelephone                                          705010731

# %%
skim(customers_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 100    │ │ string      │ 6     │                                                          │
# │ │ Number of columns │ 6      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┓  │
# │ ┃           ┃    ┃      ┃           ┃           ┃           ┃           ┃ chars per ┃ words per ┃ total      ┃  │
# │ ┃ column    ┃ NA ┃ NA % ┃ shortest  ┃ longest   ┃ min       ┃ max       ┃ row       ┃ row       ┃ words      ┃  │
# │ ┡━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━┩  │
# │ │ ClientID  │  0 │    0 │ 1         │ 100       │ 1         │ 99        │      1.92 │         1 │        100 │  │
# │ │ Nom       │  0 │    0 │ Pham      │ Cunningha │ Abbott    │ Wilson    │      6.37 │         1 │        100 │  │
# │ │           │    │      │           │ m         │           │           │           │           │            │  │
# │ │ Prenom    │  0 │    0 │ Zoe       │ Christoph │ Aaron     │ Zoe       │      6.14 │         1 │        100 │  │
# │ │           │    │      │           │ er        │           │           │           │           │            │  │
# │ │ Adresse   │  0 │    0 │ USS Lee,  │ 925       │ 00041     │ Unit 6947 │      43.5 │       7.3 │        732 │  │
# │ │           │    │      │ FPO AP    │ Robertson │ Green     │ Box 2102, │           │           │            │  │
# │ │           │    │      │ 23687     │ Springs   │ Street,   │ DPO AP    │           │           │            │  │
# │ │           │    │      │           │ Suite     │ Stephenbo │ 84355     │           │           │            │  │
# │ │           │    │      │           │ 489, Port │ rough, UT │           │           │           │            │  │
# │ │           │    │      │           │ Jeffreybe │ 34030     │           │           │           │            │  │
# │ │           │    │      │           │ rg, IN    │           │           │           │           │            │  │
# │ │           │    │      │           │ 43983     │           │           │           │           │            │  │
# │ │ Email     │  0 │    0 │ snow.zoe@ │ richardso │ abbott.kr │ wilson.vi │      23.5 │         1 │        100 │  │
# │ │           │    │      │ gmail.com │ n.cheyenn │ isten@gma │ ncent@gma │           │           │            │  │
# │ │           │    │      │           │ e@gmail.c │ il.com    │ il.com    │           │           │            │  │
# │ │           │    │      │           │ om        │           │           │           │           │            │  │
# │ │ NumeroTel │  0 │    0 │ 1375633   │ 425163679 │ 117405460 │ 994074144 │      8.86 │         1 │        100 │  │
# │ │ ephone    │    │      │           │           │           │           │           │           │            │  │
# │ └───────────┴────┴──────┴───────────┴───────────┴───────────┴───────────┴───────────┴───────────┴────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## Requêtes SQL

# %% [markdown]
# Liste des produits qui contiennent 'TV' avec LIKE

# %%
query="""
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM products_dim
-- Conditions
WHERE "NomProduit" LIKE '%%TV%%';
"""
pd.read_sql(sql=query, con=engine)
# Out:
#    ProduitID      NomProduit  \
# 0          2  Samsung TV 55'
# 1          7  Samsung TV 55'
# 2         12  Samsung TV 55'
# 3         16  Samsung TV 55'
# 4         29  Samsung TV 55'
# 5         33  Samsung TV 55'
# 6         35  Samsung TV 55'
# 7         38  Samsung TV 55'
# 8         44  Samsung TV 55'
# 9         48  Samsung TV 55'
# 10        59  Samsung TV 55'
# 11        62  Samsung TV 55'
# 12        64  Samsung TV 55'
# 13        66  Samsung TV 55'
# 14        69  Samsung TV 55'
# 15        82  Samsung TV 55'
# 16        92  Samsung TV 55'
# 17       100  Samsung TV 55'
#
#                                           Description  PrixUnitaire  \
# 0   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           129
# 1   55-inch 4K UHD Smart TV with HDR, Crystal Disp...            85
# 2   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           799
# 3   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           699
# 4   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           399
# 5   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           399
# 6   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           799
# 7   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           799
# 8   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           399
# 9   55-inch 4K UHD Smart TV with HDR, Crystal Disp...           699
# 10  55-inch 4K UHD Smart TV with HDR, Crystal Disp...            85
# 11  55-inch 4K UHD Smart TV with HDR, Crystal Disp...           299
# 12  55-inch 4K UHD Smart TV with HDR, Crystal Disp...           699
# 13  55-inch 4K UHD Smart TV with HDR, Crystal Disp...           129
# 14  55-inch 4K UHD Smart TV with HDR, Crystal Disp...           129
# 15  55-inch 4K UHD Smart TV with HDR, Crystal Disp...           129
# 16  55-inch 4K UHD Smart TV with HDR, Crystal Disp...           799
# 17  55-inch 4K UHD Smart TV with HDR, Crystal Disp...           299
#
#    FournisseurID
# 0             51
# 1             72
# 2              4
# 3             50
# 4             80
# 5             49
# 6             47
# 7             22
# 8             40
# 9             24
# 10            97
# 11            76
# 12            67
# 13            24
# 14            10
# 15            40
# 16            56
# 17            16

# %% [markdown]
# Liste des produits qui contiennent 'TV' avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM products_dim
-- Condition
WHERE "NomProduit" ~ 'TV';
"""
pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                                0  \
# ProduitID                                                      2
# NomProduit                                        Samsung TV 55'
# Description    55-inch 4K UHD Smart TV with HDR, Crystal Disp...
# PrixUnitaire                                                 129
# FournisseurID                                                 51
#
#                                                                1  \
# ProduitID                                                      7
# NomProduit                                        Samsung TV 55'
# Description    55-inch 4K UHD Smart TV with HDR, Crystal Disp...
# PrixUnitaire                                                  85
# FournisseurID                                                 72
#
#                                                                2  \
# ProduitID                                                     12
# NomProduit                                        Samsung TV 55'
# Description    55-inch 4K UHD Smart TV with HDR, Crystal Disp...
# PrixUnitaire                                                 799
# FournisseurID                                                  4
#
#                                                                3  \
# ProduitID                                                     16
# NomProduit                                        Samsung TV 55'
# Description    55-inch 4K UHD Smart TV with HDR, Crystal Disp...
# PrixUnitaire                                                 699
# FournisseurID                                                 50
#
#                                                                4
# ProduitID                                                     29
# NomProduit                                        Samsung TV 55'
# Description    55-inch 4K UHD Smart TV with HDR, Crystal Disp...
# PrixUnitaire                                                 399
# FournisseurID                                                 80

# %% [markdown]
# Liste des produits dont le nom commence par la lettre D avec LIKE

# %%
query ="""
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM products_dim
-- Condition
WHERE "NomProduit" LIKE 'D%%';
"""
pd.read_sql(sql=query, con=engine)
# Out:
#    ProduitID    NomProduit                                        Description  \
# 0          5  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 1          6   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 2         10  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 3         11  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 4         14  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 5         19  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 6         22   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 7         24   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 8         28  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 9         31   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 10        34  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 11        36  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 12        40  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 13        41   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 14        42  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 15        50   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 16        52   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 17        57  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 18        65   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 19        67   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 20        71   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 21        89   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 22        98   Dell XPS 13  13.4-inch FHD+ laptop with 10th Gen Intel Core...
# 23        99  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
#
#     PrixUnitaire FournisseurID
# 0            999            58
# 1            299            28
# 2            699            47
# 3            999            39
# 4            799            82
# 5             59            13
# 6            129            93
# 7            999            34
# 8            129            84
# 9            999             2
# 10            59            92
# 11            85            15
# 12            59            95
# 13           299            13
# 14            59            13
# 15           799            40
# 16           799            91
# 17           699            73
# 18           999             8
# 19           299            32
# 20            85            90
# 21           299            86
# 22           799            33
# 23           999            84

# %% [markdown]
# Liste des produits dont le nom commence par la lettre D avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT * 
-- BD récupérée
FROM products_dim
-- Condition
WHERE "NomProduit" ~ '^D';
"""

pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                                0  \
# ProduitID                                                      5
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 999
# FournisseurID                                                 58
#
#                                                                1  \
# ProduitID                                                      6
# NomProduit                                           Dell XPS 13
# Description    13.4-inch FHD+ laptop with 10th Gen Intel Core...
# PrixUnitaire                                                 299
# FournisseurID                                                 28
#
#                                                                2  \
# ProduitID                                                     10
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 699
# FournisseurID                                                 47
#
#                                                                3  \
# ProduitID                                                     11
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 999
# FournisseurID                                                 39
#
#                                                                4
# ProduitID                                                     14
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 799
# FournisseurID                                                 82

# %% [markdown]
# Liste des produits qui se termine par la lettre M avec LIKE

# %%
query="""
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM products_dim
-- Condition
WHERE "NomProduit" LIKE '%%m';
"""
pd.read_sql(sql=query, con=engine)
# Out:
#    ProduitID    NomProduit                                        Description  \
# 0          5  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 1         10  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 2         11  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 3         14  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 4         19  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 5         28  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 6         34  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 7         36  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 8         40  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 9         42  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 10        57  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
# 11        99  Dyson Vacuum  Cordless vacuum cleaner with strong suction po...
#
#     PrixUnitaire FournisseurID
# 0            999            58
# 1            699            47
# 2            999            39
# 3            799            82
# 4             59            13
# 5            129            84
# 6             59            92
# 7             85            15
# 8             59            95
# 9             59            13
# 10           699            73
# 11           999            84

# %% [markdown]
# Liste des produits qui se termine par la lettre M avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM products_dim
-- Condition
WHERE "NomProduit" ~ 'm$';
"""

pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                                0  \
# ProduitID                                                      5
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 999
# FournisseurID                                                 58
#
#                                                                1  \
# ProduitID                                                     10
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 699
# FournisseurID                                                 47
#
#                                                                2  \
# ProduitID                                                     11
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 999
# FournisseurID                                                 39
#
#                                                                3  \
# ProduitID                                                     14
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                 799
# FournisseurID                                                 82
#
#                                                                4
# ProduitID                                                     19
# NomProduit                                          Dyson Vacuum
# Description    Cordless vacuum cleaner with strong suction po...
# PrixUnitaire                                                  59
# FournisseurID                                                 13

# %% [markdown]
# Liste des clients dont le numéro du téléphone commence par '4' ou '5' avec LIKE

# %%
query="""
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "NumeroTelephone" LIKE '4%%' OR "NumeroTelephone" LIKE '5%%';
"""
pd.read_sql(sql=query, con=engine)
# Out:
#    ClientID        Nom     Prenom  \
# 0         1   Thompson    Shannon
# 1         2       Pham   Benjamin
# 2         6      Scott      Jacob
# 3         7  Rodriguez      Megan
# 4        12      Smith     Jeremy
# 5        14     Sylvia     Nicole
# 6        18       Soto      Holly
# 7        27      Brown   Danielle
# 8        29    Jimenez      Susan
# 9        37      Glenn     Monica
# 10       40    Johnson  Stephanie
# 11       42    Coleman     Dennis
# 12       45      Pitts     Ronald
# 13       47   Griffith      Becky
# 14       55     Rogers        Ms.
# 15       61      Floyd       Mark
# 16       62   Williams    Yesenia
# 17       70     Martin      Wayne
# 18       77   Trujillo     Angela
# 19       78   Mcdaniel    Randall
# 20       84     Jordan       Lynn
# 21       86     Wilson     Lonnie
# 22       89     Becker      Kevin
# 23       90     Medina   Kimberly
# 24       94     Norris      Ebony
# 25       95    Kennedy      Julie
# 26       97     Hunter   Kimberly
# 27       98       Hess       Ryan
#
#                                               Adresse  \
# 0                384 Howard Parks, New Tony, DE 67522
# 1   15250 Anita Pine Apt. 887, New Kristenport, AR...
# 2     474 Rogers Fork Apt. 821, Chelseabury, MO 72167
# 3           12744 Daniel Tunnel, Millerside, HI 91891
# 4                          USCGC Taylor, FPO AE 79668
# 5   68737 Beasley Fall Apt. 435, Lake Kennethshire...
# 6   48506 Foster Falls Apt. 055, Lake Cameronton, ...
# 7                732 Joshua Ways, Jamesfort, OH 72222
# 8   8140 Susan Port Suite 208, West Christopher, N...
# 9   3183 Albert Wall Suite 990, New Timothymouth, ...
# 10  386 Jermaine Plain Apt. 929, Williamsville, NM...
# 11  925 Robertson Springs Suite 489, Port Jeffreyb...
# 12  26300 Rodriguez Mission Apt. 754, Port Joel, N...
# 13                   PSC 6521, Box 4152, APO AA 74450
# 14  60258 Smith Corner Suite 604, North Kelly, FL ...
# 15          885 Garner Canyon, East Christy, CA 20864
# 16                   PSC 6015, Box 6383, APO AA 64305
# 17                   PSC 5886, Box 9105, APO AA 83417
# 18  2554 Barbara Ramp Suite 917, Lake Josephton, D...
# 19    40675 Keith Neck Apt. 957, Thomastown, MI 92257
# 20      617 Shelby Ranch Apt. 091, Amyburgh, CO 46872
# 21  95457 Matthews Court Suite 976, Caldwellside, ...
# 22  038 Connie Bridge Suite 490, North Sara, WV 02511
# 23       726 Jacob Village, Livingstonmouth, LA 97819
# 24    470 John Burg Apt. 011, Alexanderland, UT 99167
# 25          266 Russell Groves, Michaelside, OR 46570
# 26      99327 Lewis Glens, West Patrickstad, FL 88083
# 27                   Unit 4039 Box 6603, DPO AE 40744
#
#                           Email NumeroTelephone
# 0    thompson.shannon@gmail.com       425163679
# 1       pham.benjamin@gmail.com       544573781
# 2         scott.jacob@gmail.com       461756294
# 3     rodriguez.megan@gmail.com        55426480
# 4        smith.jeremy@gmail.com       458994501
# 5       sylvia.nicole@gmail.com       408607465
# 6          soto.holly@gmail.com       403071718
# 7      brown.danielle@gmail.com       590619668
# 8       jimenez.susan@gmail.com       578759133
# 9        glenn.monica@gmail.com       471358315
# 10  johnson.stephanie@gmail.com       557240325
# 11     coleman.dennis@gmail.com       516922641
# 12       pitts.ronald@gmail.com       589602136
# 13     griffith.becky@gmail.com       404708413
# 14         rogers.ms.@gmail.com       407353811
# 15         floyd.mark@gmail.com        53527748
# 16   williams.yesenia@gmail.com       535311132
# 17       martin.wayne@gmail.com       453697559
# 18    trujillo.angela@gmail.com       468557877
# 19   mcdaniel.randall@gmail.com       503119093
# 20        jordan.lynn@gmail.com       523192390
# 21      wilson.lonnie@gmail.com       537920637
# 22       becker.kevin@gmail.com       402912035
# 23    medina.kimberly@gmail.com        52252226
# 24       norris.ebony@gmail.com       517706582
# 25      kennedy.julie@gmail.com       421321855
# 26    hunter.kimberly@gmail.com       503857599
# 27          hess.ryan@gmail.com       508092073

# %% [markdown]
# Liste des clients dont le numéro de téléphone commence par '4' ou '5' avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "NumeroTelephone" ~ '^4|^5';
"""
pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                     0  \
# ClientID                                            1
# Nom                                          Thompson
# Prenom                                        Shannon
# Adresse          384 Howard Parks, New Tony, DE 67522
# Email                      thompson.shannon@gmail.com
# NumeroTelephone                             425163679
#
#                                                                  1  \
# ClientID                                                         2
# Nom                                                           Pham
# Prenom                                                    Benjamin
# Adresse          15250 Anita Pine Apt. 887, New Kristenport, AR...
# Email                                      pham.benjamin@gmail.com
# NumeroTelephone                                          544573781
#
#                                                                2  \
# ClientID                                                       6
# Nom                                                        Scott
# Prenom                                                     Jacob
# Adresse          474 Rogers Fork Apt. 821, Chelseabury, MO 72167
# Email                                      scott.jacob@gmail.com
# NumeroTelephone                                        461756294
#
#                                                          3  \
# ClientID                                                 7
# Nom                                              Rodriguez
# Prenom                                               Megan
# Adresse          12744 Daniel Tunnel, Millerside, HI 91891
# Email                            rodriguez.megan@gmail.com
# NumeroTelephone                                   55426480
#
#                                           4
# ClientID                                 12
# Nom                                   Smith
# Prenom                               Jeremy
# Adresse          USCGC Taylor, FPO AE 79668
# Email                smith.jeremy@gmail.com
# NumeroTelephone                   458994501

# %% [markdown]
# Donner la liste des clients dont le numéro de téléphone commence par 5 ou se termine par 94 avec LIKE

# %%
query="""
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "NumeroTelephone" LIKE '5%%' OR "NumeroTelephone" LIKE '%%94';
"""
pd.read_sql(sql=query, con=engine)
# Out:
#    ClientID        Nom     Prenom  \
# 0         2       Pham   Benjamin
# 1         6      Scott      Jacob
# 2         7  Rodriguez      Megan
# 3        27      Brown   Danielle
# 4        29    Jimenez      Susan
# 5        40    Johnson  Stephanie
# 6        42    Coleman     Dennis
# 7        45      Pitts     Ronald
# 8        61      Floyd       Mark
# 9        62   Williams    Yesenia
# 10       78   Mcdaniel    Randall
# 11       84     Jordan       Lynn
# 12       86     Wilson     Lonnie
# 13       90     Medina   Kimberly
# 14       94     Norris      Ebony
# 15       97     Hunter   Kimberly
# 16       98       Hess       Ryan
#
#                                               Adresse  \
# 0   15250 Anita Pine Apt. 887, New Kristenport, AR...
# 1     474 Rogers Fork Apt. 821, Chelseabury, MO 72167
# 2           12744 Daniel Tunnel, Millerside, HI 91891
# 3                732 Joshua Ways, Jamesfort, OH 72222
# 4   8140 Susan Port Suite 208, West Christopher, N...
# 5   386 Jermaine Plain Apt. 929, Williamsville, NM...
# 6   925 Robertson Springs Suite 489, Port Jeffreyb...
# 7   26300 Rodriguez Mission Apt. 754, Port Joel, N...
# 8           885 Garner Canyon, East Christy, CA 20864
# 9                    PSC 6015, Box 6383, APO AA 64305
# 10    40675 Keith Neck Apt. 957, Thomastown, MI 92257
# 11      617 Shelby Ranch Apt. 091, Amyburgh, CO 46872
# 12  95457 Matthews Court Suite 976, Caldwellside, ...
# 13       726 Jacob Village, Livingstonmouth, LA 97819
# 14    470 John Burg Apt. 011, Alexanderland, UT 99167
# 15      99327 Lewis Glens, West Patrickstad, FL 88083
# 16                   Unit 4039 Box 6603, DPO AE 40744
#
#                           Email NumeroTelephone
# 0       pham.benjamin@gmail.com       544573781
# 1         scott.jacob@gmail.com       461756294
# 2     rodriguez.megan@gmail.com        55426480
# 3      brown.danielle@gmail.com       590619668
# 4       jimenez.susan@gmail.com       578759133
# 5   johnson.stephanie@gmail.com       557240325
# 6      coleman.dennis@gmail.com       516922641
# 7        pitts.ronald@gmail.com       589602136
# 8          floyd.mark@gmail.com        53527748
# 9    williams.yesenia@gmail.com       535311132
# 10   mcdaniel.randall@gmail.com       503119093
# 11        jordan.lynn@gmail.com       523192390
# 12      wilson.lonnie@gmail.com       537920637
# 13    medina.kimberly@gmail.com        52252226
# 14       norris.ebony@gmail.com       517706582
# 15    hunter.kimberly@gmail.com       503857599
# 16          hess.ryan@gmail.com       508092073

# %% [markdown]
# Donner la liste des clients dont le numéro de téléphone commence par 5 ou se termine par 94 avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "NumeroTelephone" ~ '^5|94$';
"""
pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                                  0  \
# ClientID                                                         2
# Nom                                                           Pham
# Prenom                                                    Benjamin
# Adresse          15250 Anita Pine Apt. 887, New Kristenport, AR...
# Email                                      pham.benjamin@gmail.com
# NumeroTelephone                                          544573781
#
#                                                                1  \
# ClientID                                                       6
# Nom                                                        Scott
# Prenom                                                     Jacob
# Adresse          474 Rogers Fork Apt. 821, Chelseabury, MO 72167
# Email                                      scott.jacob@gmail.com
# NumeroTelephone                                        461756294
#
#                                                          2  \
# ClientID                                                 7
# Nom                                              Rodriguez
# Prenom                                               Megan
# Adresse          12744 Daniel Tunnel, Millerside, HI 91891
# Email                            rodriguez.megan@gmail.com
# NumeroTelephone                                   55426480
#
#                                                     3  \
# ClientID                                           27
# Nom                                             Brown
# Prenom                                       Danielle
# Adresse          732 Joshua Ways, Jamesfort, OH 72222
# Email                        brown.danielle@gmail.com
# NumeroTelephone                             590619668
#
#                                                                  4
# ClientID                                                        29
# Nom                                                        Jimenez
# Prenom                                                       Susan
# Adresse          8140 Susan Port Suite 208, West Christopher, N...
# Email                                      jimenez.susan@gmail.com
# NumeroTelephone                                          578759133

# %% [markdown]
# Donner la liste des clients dont le nom contient la lettre 'R'
# suivi de n'importe quelle autre lettre et suivi de la lettre 'C'  avec LIKE

# %%
query="""
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "Nom" LIKE 'R%%_c%%';
"""
pd.read_sql(sql=query, con=engine)
# Out:
#   ClientID         Nom    Prenom  \
# 0       46  Richardson  Cheyenne
#
#                                          Adresse  \
# 0  70396 George Trafficway, New Laurie, KS 05583
#
#                            Email NumeroTelephone
# 0  richardson.cheyenne@gmail.com       639669352

# %% [markdown]
# Donner la liste des clients dont le nom contient la lettre 'R'
# suivi de n'importe quelle autre lettre et suivi de la lettre 'C'  avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "Nom" ~ '^R.c';
"""
pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                              0
# ClientID                                                    46
# Nom                                                 Richardson
# Prenom                                                Cheyenne
# Adresse          70396 George Trafficway, New Laurie, KS 05583
# Email                            richardson.cheyenne@gmail.com
# NumeroTelephone                                      639669352

# %% [markdown]
# Liste des clients dont le nom commence par 'R' et se termine par 'A' avec LIKE

# %%
query="""
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "Nom" LIKE 'R%%%%a';
"""
pd.read_sql(sql=query, con=engine)
# Out:
#   ClientID     Nom   Prenom                                      Adresse  \
# 0       85  Rivera  Deborah  390 Danielle Valley, Martinezberg, SD 64539
#
#                       Email NumeroTelephone
# 0  rivera.deborah@gmail.com       168181172

# %% [markdown]
# Liste des clients dont le nom commence par 'R' et se termine par 'A' avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "Nom" ~ '^R.*a$';
"""
pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                            0
# ClientID                                                  85
# Nom                                                   Rivera
# Prenom                                               Deborah
# Adresse          390 Danielle Valley, Martinezberg, SD 64539
# Email                               rivera.deborah@gmail.com
# NumeroTelephone                                    168181172

# %% [markdown]
# Liste des clients dont le nom contient 'it' ou 'ie' ou 'il' ou 'is' avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "Nom" ~ 'i[tels]';
"""
pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                          0  \
# ClientID                                                10
# Nom                                                Wilkins
# Prenom                                            Patricia
# Adresse          400 Tate Glen, Port Kristenfurt, OH 07250
# Email                           wilkins.patricia@gmail.com
# NumeroTelephone                                  888856897
#
#                                           1  \
# ClientID                                 12
# Nom                                   Smith
# Prenom                               Jeremy
# Adresse          USCGC Taylor, FPO AE 79668
# Email                smith.jeremy@gmail.com
# NumeroTelephone                   458994501
#
#                                                                  2  \
# ClientID                                                        15
# Nom                                                          Smith
# Prenom                                                     Cynthia
# Adresse          382 Daniel Groves Suite 995, East Sherryfurt, ...
# Email                                      smith.cynthia@gmail.com
# NumeroTelephone                                          219759485
#
#                                                                 3  \
# ClientID                                                       17
# Nom                                                      Carrillo
# Prenom                                                    Brianna
# Adresse          543 Austin Rest Apt. 109, East Amystad, FL 57767
# Email                                  carrillo.brianna@gmail.com
# NumeroTelephone                                         670055675
#
#                                                                4
# ClientID                                                      20
# Nom                                                        Smith
# Prenom                                                    Justin
# Adresse          603 Daniel Lakes Apt. 472, New Sandra, CT 81632
# Email                                     smith.justin@gmail.com
# NumeroTelephone                                        843655697

# %% [markdown]
# Liste des clients dont le nom contient la lettre 'i' suivi d'une lettre comprise entre 'f' et 't' avec REGEXP

# %%
query = """
-- Colonnes récupérées
SELECT *
-- BD récupérée
FROM customers_dim
-- Condition
WHERE "Nom" ~ 'i[f-t]';
"""
pd.read_sql(sql=query, con=engine).head().transpose()
# Out:
#                                                                  0  \
# ClientID                                                         3
# Nom                                                      Rodriguez
# Prenom                                                      Bonnie
# Adresse          515 Henderson Coves Apt. 298, Lewismouth, OR 1...
# Email                                   rodriguez.bonnie@gmail.com
# NumeroTelephone                                          956054323
#
#                                                          1  \
# ClientID                                                 7
# Nom                                              Rodriguez
# Prenom                                               Megan
# Adresse          12744 Daniel Tunnel, Millerside, HI 91891
# Email                            rodriguez.megan@gmail.com
# NumeroTelephone                                   55426480
#
#                                                      2  \
# ClientID                                             8
# Nom                                            Collins
# Prenom                                       Alexander
# Adresse          231 Eric Spring, Paulahaven, SD 79669
# Email                      collins.alexander@gmail.com
# NumeroTelephone                              878299289
#
#                                                          3  \
# ClientID                                                10
# Nom                                                Wilkins
# Prenom                                            Patricia
# Adresse          400 Tate Glen, Port Kristenfurt, OH 07250
# Email                           wilkins.patricia@gmail.com
# NumeroTelephone                                  888856897
#
#                                           4
# ClientID                                 12
# Nom                                   Smith
# Prenom                               Jeremy
# Adresse          USCGC Taylor, FPO AE 79668
# Email                smith.jeremy@gmail.com
# NumeroTelephone                   458994501
